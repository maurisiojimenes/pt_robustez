# %%
import graficas as g
import entropia as en
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import importlib
import time

# %%
importlib.reload(en)
importlib.reload(g)
# Out:
# <module 'graficas' from 'C:\\Users\\blond\\repositorios\\pt_robustez\\graficas.py'>

# %%
G_BA = g.crear_grafica('barabasi',500,15,0)
G_WS = g.crear_grafica('watts',500,15,0.5)

# %%
indices_robustez_BA_1 = []
indices_robustez_WS_1 = []
indices_robustez_BA_2 = []
indices_robustez_WS_2 = []

inicio = time.time()

for i in range(1,len(G_BA)):
    print(f"Iteración: {i}")
    G_1 = G_BA.copy()
    G_2 = G_WS.copy()
    G_3 = G_BA.copy()
    G_4 = G_WS.copy()
    
    indice_robustez_BA_1 = g.indice_robustez(G_1,g.LCC,1,'random',i)
    indice_robustez_WS_1 = g.indice_robustez(G_2,g.LCC,1,'random',i)
    indice_robustez_BA_2 = g.indice_robustez(G_3,g.LCC,2,'random',i)
    indice_robustez_WS_2 = g.indice_robustez(G_4,g.LCC,2,'random',i)
    
    
    punto_quiebre_1 = 
    
    punto_quiebre_2 = 
    
    
    indices_robustez_BA_1.append(indice_robustez_BA_1)
    indices_robustez_WS_1.append(indice_robustez_WS_1)
    indices_robustez_BA_2.append(indice_robustez_BA_2)
    indices_robustez_WS_2.append(indice_robustez_WS_2)

final = time.time()
print(f"El tiempo de ejecución es: {final - inicio}")
# Out:
# Iteración: 1
# 0.002 0.002 1.0 1.0
# Iteración: 2
# 0.002 0.002 1.0 1.0
# Iteración: 3
# 0.002 0.002 1.0 1.0
# Iteración: 4
# 0.002 0.002 1.0 1.0
# Iteración: 5
# 0.002 0.002 1.0 1.0
# Iteración: 6
# 0.002 0.002 1.0 1.0
# Iteración: 7
# 0.002 0.002 1.0 1.0
# Iteración: 8
# 0.002 0.002 1.0 1.0
# Iteración: 9
# 0.002 0.002 1.0 1.0
# Iteración: 10
# 0.0020000000000000005 0.0020000000000000005 1.0 1.0
# Iteración: 11
# 0.0020000000000000005 0.0020000000000000005 1.0 1.0
# Iteración: 12
# 0.0020000000000000005 0.0020000000000000005 1.0 1.0
# Iteración: 13
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 14
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 15
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 16
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 17
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 18
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 19
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 20
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 21
# 0.002000000000000001 0.002000000000000001 1.0 1.0
# Iteración: 22
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 23
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 24
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 25
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 26
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 27
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 28
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 29
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 30
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 31
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 32
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 33
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 34
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 35
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 36
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 37
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 38
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 39
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 40
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 41
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 42
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 43
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 44
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 45
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 46
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 47
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 48
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 49
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 50
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 51
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 52
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 53
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 54
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 55
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 56
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 57
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 58
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 59
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 60
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 61
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 62
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 63
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 64
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 65
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 66
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 67
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 68
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 69
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 70
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 71
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 72
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 73
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 74
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 75
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 76
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 77
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 78
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 79
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 80
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 81
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 82
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 83
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 84
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 85
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 86
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 87
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 88
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 89
# 0.0020000000000000013 0.0020000000000000013 1.0 1.0
# Iteración: 90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-630c7bb60581> in <module>
#      13     indice_robustez_BA_1 = g.indice_robustez(G_1,g.LCC,1,'random',i)
#      14     indice_robustez_WS_1 = g.indice_robustez(G_2,g.LCC,1,'random',i)
# ---> 15     indice_robustez_BA_2 = g.indice_robustez(G_3,g.LCC,2,'random',i)
#      16     indice_robustez_WS_2 = g.indice_robustez(G_4,g.LCC,2,'random',i)
#      17
#
# ~\repositorios\pt_robustez\graficas.py in indice_robustez(G, f, w, criterio, k)
#     103     for i in range(k):
#     104         G = ataques(G,criterio)
# --> 105         f_i.append(f(G))
#     106         if w == 1:
#     107             w_i.append(1/N)
#
# ~\repositorios\pt_robustez\graficas.py in LCC(G)
#      76     if len(G) == 0:
#      77         return 0
# ---> 78     componente_mas_grande = max(nx.connected_components(G), key=len)
#      79     proporcion = len(componente_mas_grande)/N
#      80     return proporcion
#
# ~\miniconda3\envs\PT\lib\site-packages\networkx\algorithms\components\connected.py in connected_components(G)
#      62     for v in G:
#      63         if v not in seen:
# ---> 64             c = _plain_bfs(G, v)
#      65             seen.update(c)
#      66             yield c
#
# ~\miniconda3\envs\PT\lib\site-packages\networkx\algorithms\components\connected.py in _plain_bfs(G, source)
#     183         for v in thislevel:
#     184             if v not in seen:
# --> 185                 seen.add(v)
#     186                 nextlevel.update(G_adj[v])
#     187     return seen
#
# KeyboardInterrupt:
