# %%
import graficas as g
import entropia as en
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import importlib
import time

# %%
importlib.reload(en)
importlib.reload(g)
# Out:
# <module 'graficas' from 'C:\\proyectos\\repositorios\\pt_robustez\\graficas.py'>

# %%
n = 1000
m = 5
num_simulaciones = 5

# %%
inicio = time.time()

IR_BA_fallos = []
IR_WS_fallos = []

for i in range(num_simulaciones):
    print(f"estamos en la simulación {i}")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        #print(f"Hemos obtenido el k_{j}")
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,g.grado_promedio,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,g.grado_promedio,2,'random',j))
    IR_BA_fallos.append(IR_BA)
    IR_WS_fallos.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# estamos en la simulación 0
# estamos en la simulación 1
# estamos en la simulación 2
# estamos en la simulación 3
# estamos en la simulación 4
# El tiempo de ejecución fue de: 907.4505846500397
# 1.0757958335562323 0
# 0.9766916485126845 0
# iteración: 149
# 1.0756797517571568 0
# 0.9764682183080305 0
# iteración: 150
# 1.0755622260942497 0
# 0.9762446787393958 0
# iteración: 151
# 1.075442252742718 0
# 0.9760186072495106 0
# iteración: 152
# 1.075319446241423 0
# 0.975790319556897 0
# iteración: 153
# 1.0751939556873276 0
# 0.9755613280338601 0
# iteración: 154
# 1.0750653668535264 0
# 0.9753316271411411 0
# iteración: 155
# 1.0749345893198927 0
# 0.9751011472422588 0
# iteración: 156
# 1.0748008542274676 0
# 0.9748698629790068 0
# iteración: 157
# 1.0746652644787265 0
# 0.9746386704119113 0
# iteración: 158
# 1.074526667329981 0
# 0.9744065800258379 0
# iteración: 159
# 1.0743856302045864 0
# 0.9741699527728049 0
# iteración: 160
# 1.074241736761503 0
# 0.973933432855682 0
# ...

# %%
inicio = time.time()

IR_BA_ataques = []
IR_WS_ataques = []

for i in range(num_simulaciones):
    print(f"estamos en la simulación {i}")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        #print(f"Hemos obtenido el k_{j}")
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,g.grado_promedio,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,g.grado_promedio,2,'degree',j))
    IR_BA_ataques.append(IR_BA)
    IR_WS_ataques.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# estamos en la simulación 0
# estamos en la simulación 1
# estamos en la simulación 2
# estamos en la simulación 3
# estamos en la simulación 4
# El tiempo de ejecución fue de: 1672.3240723609924

# %%
resultados_GP_BA_fallos = [sum(col) / num_simulaciones for col in zip(*IR_BA_fallos)]
resultados_GP_WS_fallos = [sum(col) / num_simulaciones for col in zip(*IR_WS_fallos)]


resultados_GP_BA_ataques = [sum(col) / num_simulaciones for col in zip(*IR_BA_ataques)]
resultados_GP_WS_ataques = [sum(col) / num_simulaciones for col in zip(*IR_WS_ataques)]

# %%
N=1000
inicio = time.time()

IR_BA_fallos = []
IR_WS_fallos = []

f = lambda G: g.densidad(G,N)

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,f,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,f,2,'random',j))
    IR_BA_fallos.append(IR_BA)
    IR_WS_fallos.append(IR_WS)
    
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 942.858128786087

# %%
N=1000
inicio = time.time()

IR_BA_ataques = []
IR_WS_ataques = []

f = lambda G: g.densidad(G,N)

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA) v
    IR_BA=[]
    IR_WS=[]
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,f,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,f,2,'degree',j))
    IR_BA_ataques.append(IR_BA)
    IR_WS_ataques.append(IR_WS)
    
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 5408.231497049332

# %%
resultados_D_BA_fallos = [sum(col) / num_simulaciones for col in zip(*IR_BA_fallos)]
resultados_D_WS_fallos = [sum(col) / num_simulaciones for col in zip(*IR_WS_fallos)]


resultados_D_BA_ataques = [sum(col) / num_simulaciones for col in zip(*IR_BA_ataques)]
resultados_D_WS_ataques = [sum(col) / num_simulaciones for col in zip(*IR_WS_ataques)]

# %%
inicio = time.time()

IR_BA_fallos=[]
IR_WS_fallos=[]

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    IR_BA=[]
    IR_WS=[]
    for j in range(1,N,1):    
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,g.componentes_conexas,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,g.componentes_conexas,2,'random',j))
    IR_BA_fallos.append(IR_BA)
    IR_WS_fallos.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 4515.712856054306

# %%
inicio = time.time()

IR_BA_ataques=[]
IR_WS_ataques=[]

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    IR_BA=[]
    IR_WS=[]
    for j in range(1,N,1):    
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,g.componentes_conexas,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,g.componentes_conexas,2,'degree',j))
    IR_BA_ataques.append(IR_BA)
    IR_WS_ataques.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 2833.219325065613

# %%
resultados_NCC_BA_fallos = [sum(col) / num_simulaciones for col in zip(*IR_BA_fallos)]
resultados_NCC_WS_fallos = [sum(col) / num_simulaciones for col in zip(*IR_WS_fallos)]


resultados_NCC_BA_ataques = [sum(col) / num_simulaciones for col in zip(*IR_BA_ataques)]
resultados_NCC_WS_ataques = [sum(col) / num_simulaciones for col in zip(*IR_WS_ataques)]

# %%
N=1000
inicio = time.time()

LCC_BA_fallos_1 = []
LCC_WS_fallos_1 = []
LCC_BA_fallos_2 = []
LCC_WS_fallos_2 = []

f_1 = lambda G: g.LCC(G,1,N)
f_2 = lambda G: g.LCC(G,2,N)

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    N = len(G_BA)
    LCC_BA_1 = []
    LCC_WS_1 = []
    LCC_BA_2 = []
    LCC_WS_2 = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        LCC_BA_1.append(g.indice_robustez(G_1,f_1,2,'random',j))
        LCC_WS_1.append(g.indice_robustez(G_2,f_1,2,'random',j))
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        LCC_BA_2.append(g.indice_robustez(G_1,f_2,2,'random',j))
        LCC_WS_2.append(g.indice_robustez(G_2,f_2,2,'random',j))
    LCC_BA_fallos_1.append(LCC_BA_1)
    LCC_WS_fallos_1.append(LCC_WS_1)
    LCC_BA_fallos_2.append(LCC_BA_2)
    LCC_WS_fallos_2.append(LCC_WS_2)
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 102642.87150216103

# %%
N = 1000

inicio = time.time()

LCC_BA_ataques_1 = []
LCC_WS_ataques_1 = []
LCC_BA_ataques_2 = []
LCC_WS_ataques_2 = []

f_1 = lambda G: g.LCC(G,1,N)
f_2 = lambda G: g.LCC(G,2,N)

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    LCC_BA_1 = []
    LCC_WS_1 = []
    LCC_BA_2 = []
    LCC_WS_2 = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        LCC_BA_1.append(g.indice_robustez(G_1,f_1,2,'degree',j))
        LCC_WS_1.append(g.indice_robustez(G_2,f_1,2,'degree',j))
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        LCC_BA_2.append(g.indice_robustez(G_1,f_2,2,'degree',j))
        LCC_WS_2.append(g.indice_robustez(G_2,f_2,2,'degree',j))
    LCC_BA_ataques_1.append(LCC_BA_1)
    LCC_WS_ataques_1.append(LCC_WS_1)
    LCC_BA_ataques_2.append(LCC_BA_2)
    LCC_WS_ataques_2.append(LCC_WS_2)
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Vamos en la 0 iteración
# Vamos en la 1 iteración
# Vamos en la 2 iteración
# Vamos en la 3 iteración
# Vamos en la 4 iteración
# El tiempo de ejecución fue de: 12476.510693073273

# %%
resultados_LCC_BA_fallos_1 = [sum(col)/num_simulaciones for col in zip(*LCC_BA_fallos_1)]
resultados_LCC_WS_fallos_1 = [sum(col)/num_simulaciones for col in zip(*LCC_WS_fallos_1)]
resultados_LCC_BA_fallos_2 = [sum(col)/num_simulaciones for col in zip(*LCC_BA_fallos_2)]
resultados_LCC_WS_fallos_2 = [sum(col)/num_simulaciones for col in zip(*LCC_WS_fallos_2)]

resultados_LCC_BA_ataques_1 = [sum(col) / num_simulaciones for col in zip(*LCC_BA_ataques_1)]
resultados_LCC_WS_ataques_1 = [sum(col) / num_simulaciones for col in zip(*LCC_WS_ataques_1)]
resultados_LCC_BA_ataques_2 = [sum(col) / num_simulaciones for col in zip(*LCC_BA_ataques_2)]
resultados_LCC_WS_ataques_2 = [sum(col) / num_simulaciones for col in zip(*LCC_WS_ataques_2)]

# %%
# Colores definidos
blue_dark = "#0e3d66"
blue_light = "#5a9bd4"
orange_dark = "#cc6600"
orange_light = "#f4a259"

x = np.linspace(0, 1, len(resultados_GP_BA_fallos))

fig, axs = plt.subplots(2, 4, figsize=(24, 10), sharex=True)

# --- GP ---
axs[0, 0].plot(x, resultados_GP_BA_fallos, label="BA-model", linestyle='--', color=blue_light)
axs[0, 0].plot(x, resultados_GP_WS_fallos, label="WS-model", color=orange_light)
axs[0, 0].set_title("Average degree under random failure scenario")
axs[0, 0].set_ylabel("Average degree")
axs[0, 0].legend()
axs[0, 0].grid(True)

axs[1, 0].plot(x, resultados_GP_BA_ataques, label="BA-model", linestyle='--', color=blue_light)
axs[1, 0].plot(x, resultados_GP_WS_ataques, label="WS-model", color=orange_light)
axs[1, 0].set_title("Average degree under attacks by highest degree")
axs[1, 0].set_xlabel(r"$\delta$")
axs[1, 0].set_ylabel("Average degree")
axs[1, 0].legend()
axs[1, 0].grid(True)

# --- Density ---
axs[0, 1].plot(x, resultados_D_BA_fallos, label="BA-model", linestyle='--', color=blue_light)
axs[0, 1].plot(x, resultados_D_WS_fallos, label="WS-model", color=orange_light)
axs[0, 1].set_title("Density under random failure scenario")
axs[0, 1].set_ylabel("Density")
axs[0, 1].legend()
axs[0, 1].grid(True)

axs[1, 1].plot(x, resultados_D_BA_ataques, label="BA-model", linestyle='--', color=blue_light)
axs[1, 1].plot(x, resultados_D_WS_ataques, label="WS-model", color=orange_light)
axs[1, 1].set_title("Density under attacks by highest degree")
axs[1, 1].set_xlabel(r"$\delta$")
axs[1, 1].set_ylabel("Density")
axs[1, 1].legend()
axs[1, 1].grid(True)

# --- NCC ---
axs[0, 2].plot(x, resultados_NCC_BA_fallos, label="BA-model", linestyle='--', color=blue_dark)
axs[0, 2].plot(x, resultados_NCC_WS_fallos, label="WS-model", color=orange_dark)
axs[0, 2].set_title("NCC under random failure scenario")
axs[0, 2].set_ylabel("NCC")
axs[0, 2].legend()
axs[0, 2].grid(True)

axs[1, 2].plot(x, resultados_NCC_BA_ataques, label="BA-model", linestyle='--', color=blue_dark)
axs[1, 2].plot(x, resultados_NCC_WS_ataques, label="WS-model", color=orange_dark)
axs[1, 2].set_title("NCC under attacks by highest degree")
axs[1, 2].set_xlabel(r"$\delta$")
axs[1, 2].set_ylabel("NCC")
axs[1, 2].legend()
axs[1, 2].grid(True)

# --- LCC (4 curvas) ---
axs[0, 3].plot(x, resultados_LCC_BA_fallos_1, label=r"BA-model-$\frac{1}{N}$", linestyle='--', color=blue_dark)
axs[0, 3].plot(x, resultados_LCC_WS_fallos_1, label=r"WS-model-$\frac{1}{N}$", linestyle='-', color=orange_dark)
axs[0, 3].plot(x, resultados_LCC_BA_fallos_2, label=r"BA-model-$\frac{1}{N-i}$", linestyle='--', color=blue_light)
axs[0, 3].plot(x, resultados_LCC_WS_fallos_2, label=r"WS-model-$\frac{1}{N-i}$", linestyle='-', color=orange_light)
axs[0, 3].set_title("LCC under random failure scenario")
axs[0, 3].set_ylabel("LCC")
axs[0, 3].legend()
axs[0, 3].grid(True)

axs[1, 3].plot(x, resultados_LCC_BA_ataques_1, label=r"BA-model-$\frac{1}{N}$", linestyle='--', color=blue_dark)
axs[1, 3].plot(x, resultados_LCC_WS_ataques_1, label=r"WS-model-$\frac{1}{N}$", linestyle='-', color=orange_dark)
axs[1, 3].plot(x, resultados_LCC_BA_ataques_2, label=r"BA-model-$\frac{1}{N-i}$", linestyle='--', color=blue_light)
axs[1, 3].plot(x, resultados_LCC_WS_ataques_2, label=r"WS-model-$\frac{1}{N-i}$", linestyle='-', color=orange_light)
axs[1, 3].set_title("LCC under attacks by highest degree")
axs[1, 3].set_xlabel(r"$\delta$")
axs[1, 3].set_ylabel("LCC")
axs[1, 3].legend()
axs[1, 3].grid(True)

# --- Ajustes finales ---
plt.tight_layout()
plt.subplots_adjust(top=0.93, wspace=0.3, hspace=0.4)
plt.suptitle("Structural Connectivity Measures", fontsize=16)
plt.savefig("medidas_estructurales_todas.png", dpi=300)
plt.show()

# %%
inicio = time.time()

H_1_BA_fallos = []
H_1_WS_fallos = []

for i in range(num_simulaciones):
    print(f"estamos en la {i} simulación")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_shanon_1,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_shanon_1,2,'random',j))
    H_1_BA_fallos.append(IR_BA)
    H_1_WS_fallos.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# estamos en la 0 simulación
# estamos en la 1 simulación
# estamos en la 2 simulación
# estamos en la 3 simulación
# estamos en la 4 simulación
# El tiempo de ejecución fue de: 4937.784432411194

# %%
N = len(G_BA)

inicio = time.time()

H_1_BA_ataques = []
H_1_WS_ataques = []

for i in range(num_simulaciones):
    print(f"Estamos en la {i} simulación")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_shanon_1,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_shanon_1,2,'degree',j))
    H_1_BA_ataques.append(IR_BA)
    H_1_WS_ataques.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# Estamos en la 0 simulación
# Estamos en la 1 simulación
# Estamos en la 2 simulación
# Estamos en la 3 simulación
# Estamos en la 4 simulación
# El tiempo de ejecución fue de: 43909.33267855644

# %%
resultados_H_1_BA_fallos = [sum(col) for col in zip(*H_1_BA_fallos)]
resultados_H_1_WS_fallos = [sum(col) for col in zip(*H_1_WS_fallos)]

resultados_H_1_BA_ataques = [sum(col) for col in zip(*H_1_BA_ataques)]
resultados_H_1_WS_ataques = [sum(col) for col in zip(*H_1_WS_ataques)]

# %%
H_2_BA_fallos = []
H_2_WS_fallos = []


inicio = time.time()

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA=[]
    IR_WS=[]
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_shanon_normalizada,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_normalizada,2,'random',j))
    H_2_BA_fallos.append(IR_BA)
    H_2_WS_fallos.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")

# %%
H_2_BA_ataques = []
H_2_WS_ataques = []


inicio = time.time()

for i in range(num_simulaciones):
    print(f"Vamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA=[]
    IR_WS=[]
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_normalizada,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_normalizada,2,'degree',j))
    H_2_BA_ataques.append(IR_BA)
    H_2_WS_ataques.append(IR_WS)

final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")

# %%
resultados_H_2_BA_fallos = [sum(col)/num_simulaciones for col in zip(*H_2_BA_fallos)]
resultados_H_2_WS_fallos = [sum(col)/num_simulaciones for col in zip(*H_2_WS_fallos)]

resultados_H_2_BA_ataques = [sum(col)/num_simulaciones for col in zip(*H_2_BA_ataques)]
resultados_H_2_WS_ataques = [sum(col)/num_simulaciones for col in zip(*H_2_WS_ataques)]

# %%
inicio = time.time()

H_3_BA_fallos = []
H_3_WS_fallos = []

for i in range(num_simulaciones):
    print(f"estamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_shanon_2,2,'random',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_shanon_2,2,'random',j))
    H_3_BA_fallos.append(IR_BA)
    H_3_WS_fallos.append(IR_WS)
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# estamos en la 0 iteración
# estamos en la 1 iteración
# estamos en la 2 iteración
# estamos en la 3 iteración
# estamos en la 4 iteración
# El tiempo de ejecución fue de: 1520.1739928722382

# %%
inicio = time.time()

H_3_BA_ataques = []
H_3_WS_ataques = []

for i in range(num_simulaciones):
    print(f"estamos en la {i} iteración")
    G_BA = g.crear_grafica('barabasi',n,m,0)
    G_WS = g.crear_grafica('watts',n,2*m,0.5)
    IR_BA = []
    IR_WS = []
    for j in range(1,N,1):
        G_1 = G_BA.copy()
        G_2 = G_WS.copy()
        IR_BA.append(g.indice_robustez(G_1,en.entropia_shanon_2,2,'degree',j))
        IR_WS.append(g.indice_robustez(G_2,en.entropia_shanon_2,2,'degree',j))
    H_3_BA_ataques.append(IR_BA)
    H_3_WS_ataques.append(IR_WS)
final = time.time()

print(f"El tiempo de ejecución fue de: {final - inicio}")
# Out:
# estamos en la 0 iteración
# estamos en la 1 iteración
# estamos en la 2 iteración
# estamos en la 3 iteración
# estamos en la 4 iteración
# El tiempo de ejecución fue de: 2336.931702852249

# %%
resultados_H_3_BA_fallos = [sum(col)/num_simulaciones for col in zip(*H_3_BA_fallos)]
resultados_H_3_WS_fallos = [sum(col)/num_simulaciones for col in zip(*H_3_WS_fallos)]

resultados_H_3_BA_ataques = [sum(col)/num_simulaciones for col in zip(*H_3_BA_ataques)]
resultados_H_3_WS_ataques = [sum(col)/num_simulaciones for col in zip(*H_3_WS_ataques)]

# %%
# Colores
blue_dark = "#0e3d66"
orange_dark = "#cc6600"

# Asumiendo que todas las listas tienen la misma longitud
delta = np.linspace(0, 1, len(resultados_H_1_BA_fallos))

# Crear figura y ejes
fig, axs = plt.subplots(2, 2, figsize=(18, 10))
axs = axs.flatten()

# Lista con todos los datos, títulos y etiquetas
graficas = [
    (resultados_H_1_BA_fallos, resultados_H_1_WS_fallos, r"$H_1^{Shanon}$ entropy under random failure scenario"),
    (resultados_H_3_BA_fallos, resultados_H_3_WS_fallos, r"$H_2^{Shanon}$ entropy under random failure scenario"),
    (resultados_H_1_BA_ataques, resultados_H_1_WS_ataques, r"$H_1^{Shanon}$ entropy under attacks by highest degree"),
    (resultados_H_3_BA_ataques, resultados_H_3_WS_ataques, r"$H_2^{Shanon}$ entropy under attacks by highest degree"),
]

# Graficar
for i, (ba, ws, titulo) in enumerate(graficas):
    ax = axs[i]
    ax.plot(delta, ba, label="BA-model", color=blue_dark,linestyle='--')
    ax.plot(delta, ws, label="WS-model", color=orange_dark)
    ax.set_title(titulo, fontsize=12)
    ax.set_xlabel(r"$\delta$")
    ax.set_ylabel(fr"$H_{{{i//2 + 1}}}$")
    ax.set_xlim(0, 1)
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig("IR_entropia_shanon.png",dpi=300)
plt.show()

# %%
#AHORA HAY QUE PROGRAMAR TSALLIS Y HACER LO MISMO PARA DKL
