# %%
import graficas as g
import entropia as en
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import importlib
import time

# %%
importlib.reload(en)
importlib.reload(g)
# Out:
# <module 'graficas' from 'C:\\Users\\blond\\repositorios\\pt_robustez\\graficas.py'>

# %%
G_BA = g.crear_grafica('barabasi',500,15,0)
G_WS = g.crear_grafica('watts',500,15,0.5)

# %%
indices_robustez_BA = []
indices_robustez_WS = []

for i in range(1,len(G_barabasi)):
    print(f"Vamos en el paso dónde k = {i}")
    G_1 = G_BA.copy()
    G_2 = G_WS.copy()
    indice_robustez_BA = g.indice_robustez(G_1,g.grado_promedio,1,'random',i)
    indice_robustez_WS = g.indice_robustez(G_2,g.grado_promedio,1,'random',i)
    indices_robustez_BA.append(indice_robustez_BA)
    indices_robustez_WS.append(indice_robustez_WS)
# Out:
# Vamos en el paso dónde k = 1
# Vamos en el paso dónde k = 2
# Vamos en el paso dónde k = 3
# Vamos en el paso dónde k = 4
# Vamos en el paso dónde k = 5
# Vamos en el paso dónde k = 6
# Vamos en el paso dónde k = 7
# Vamos en el paso dónde k = 8
# Vamos en el paso dónde k = 9
# Vamos en el paso dónde k = 10
# Vamos en el paso dónde k = 11
# Vamos en el paso dónde k = 12
# Vamos en el paso dónde k = 13
# Vamos en el paso dónde k = 14
# Vamos en el paso dónde k = 15
# Vamos en el paso dónde k = 16
# Vamos en el paso dónde k = 17
# Vamos en el paso dónde k = 18
# Vamos en el paso dónde k = 19
# Vamos en el paso dónde k = 20
# Vamos en el paso dónde k = 21
# Vamos en el paso dónde k = 22
# Vamos en el paso dónde k = 23
# Vamos en el paso dónde k = 24
# Vamos en el paso dónde k = 25
# Vamos en el paso dónde k = 26
# Vamos en el paso dónde k = 27
# Vamos en el paso dónde k = 28
# Vamos en el paso dónde k = 29
# Vamos en el paso dónde k = 30
# Vamos en el paso dónde k = 31
# ...

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo el grado promedio',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo el grado promedio',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes y medida usada para los índices')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo el grado promedio',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo el grado promedio',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.xscale('log')
plt.yscale('log')
plt.legend(title='Modelos de redes y medida usada para los índices')
plt.grid(True)
plt.show()

# %%
indices_robustez_BA = []
indices_robustez_WS = []

for i in range(1,len(G_barabasi)):
    print(f"Vamos en el paso dónde k = {i}")
    G_1 = G_BA.copy() 
    G_2 = G_WS.copy()
    indice_robustez_BA = g.indice_robustez(G_1,en.entropia_normalizada_1,1,'random',i)
    indice_robustez_WS = g.indice_robustez(G_2,en.entropia_normalizada_1,1,'random',i)
    indices_robustez_BA.append(indice_robustez_BA)
    indices_robustez_WS.append(indice_robustez_WS)
# Out:
# Vamos en el paso dónde k = 1
# Vamos en el paso dónde k = 2
# Vamos en el paso dónde k = 3
# Vamos en el paso dónde k = 4
# Vamos en el paso dónde k = 5
# Vamos en el paso dónde k = 6
# Vamos en el paso dónde k = 7
# Vamos en el paso dónde k = 8
# Vamos en el paso dónde k = 9
# Vamos en el paso dónde k = 10
# Vamos en el paso dónde k = 11
# Vamos en el paso dónde k = 12
# Vamos en el paso dónde k = 13
# Vamos en el paso dónde k = 14
# Vamos en el paso dónde k = 15
# Vamos en el paso dónde k = 16
# Vamos en el paso dónde k = 17
# Vamos en el paso dónde k = 18
# Vamos en el paso dónde k = 19
# Vamos en el paso dónde k = 20
# Vamos en el paso dónde k = 21
# Vamos en el paso dónde k = 22
# Vamos en el paso dónde k = 23
# Vamos en el paso dónde k = 24
# Vamos en el paso dónde k = 25
# Vamos en el paso dónde k = 26
# Vamos en el paso dónde k = 27
# Vamos en el paso dónde k = 28
# Vamos en el paso dónde k = 29
# Vamos en el paso dónde k = 30
# Vamos en el paso dónde k = 31
# ...

# %%
indices_robustez_BA = []
indices_robustez_WS = []

for i in range(1,len(G_barabasi)):
    print(f"Vamos en el paso dónde k = {i}")
    G_1 = G_BA.copy()
    G_2 = G_WS.copy()
    indice_robustez_BA = g.indice_robustez(G_1,g.grado_promedio,1,'degree',i)
    indice_robustez_WS = g.indice_robustez(G_2,g.grado_promedio,1,'degree',i)
    indices_robustez_BA.append(indice_robustez_BA)
    indices_robustez_WS.append(indice_robustez_WS)
# Out:
# Vamos en el paso dónde k = 1
# Vamos en el paso dónde k = 2
# Vamos en el paso dónde k = 3
# Vamos en el paso dónde k = 4
# Vamos en el paso dónde k = 5
# Vamos en el paso dónde k = 6
# Vamos en el paso dónde k = 7
# Vamos en el paso dónde k = 8
# Vamos en el paso dónde k = 9
# Vamos en el paso dónde k = 10
# Vamos en el paso dónde k = 11
# Vamos en el paso dónde k = 12
# Vamos en el paso dónde k = 13
# Vamos en el paso dónde k = 14
# Vamos en el paso dónde k = 15
# Vamos en el paso dónde k = 16
# Vamos en el paso dónde k = 17
# Vamos en el paso dónde k = 18
# Vamos en el paso dónde k = 19
# Vamos en el paso dónde k = 20
# Vamos en el paso dónde k = 21
# Vamos en el paso dónde k = 22
# Vamos en el paso dónde k = 23
# Vamos en el paso dónde k = 24
# Vamos en el paso dónde k = 25
# Vamos en el paso dónde k = 26
# Vamos en el paso dónde k = 27
# Vamos en el paso dónde k = 28
# Vamos en el paso dónde k = 29
# Vamos en el paso dónde k = 30
# Vamos en el paso dónde k = 31
# ...

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo el grado promedio',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo el grado promedio',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes y medida usada para los índices')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo el grado promedio',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo el grado promedio',color='red',markersize=1)
plt.xscale('log')
plt.yscale('log')
plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes y medida usada para los índices')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo la entropía normalizada',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo la entropía normalizada',color='red',markersize=1)
plt.xscale('log')
plt.yscale('log')
plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes y entropía')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA con f cómo la entropía normalizada',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS con f cómo la entropía normalizada',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez')
plt.xlabel('k')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes y entropía')
plt.grid(True)
plt.show()

# %%
indices_robustez_BA = []
indices_robustez_WS = []

for i in range(1,len(G_barabasi)):
    print(f"Vamos en el paso dónde k = {i}")
    G_1 = G_BA.copy() 
    G_2 = G_WS.copy()
    indice_robustez_BA = g.indice_robustez(G_1,en.entropia_distribucion_1,1,'random',i)
    indice_robustez_WS = g.indice_robustez(G_2,en.entropia_distribucion_1,1,'random',i)
    indices_robustez_BA.append(indice_robustez_BA)
    indices_robustez_WS.append(indice_robustez_WS)
# Out:
# Vamos en el paso dónde k = 1
# Vamos en el paso dónde k = 2
# Vamos en el paso dónde k = 3
# Vamos en el paso dónde k = 4
# Vamos en el paso dónde k = 5
# Vamos en el paso dónde k = 6
# Vamos en el paso dónde k = 7
# Vamos en el paso dónde k = 8
# Vamos en el paso dónde k = 9
# Vamos en el paso dónde k = 10
# Vamos en el paso dónde k = 11
# Vamos en el paso dónde k = 12
# Vamos en el paso dónde k = 13
# Vamos en el paso dónde k = 14
# Vamos en el paso dónde k = 15
# Vamos en el paso dónde k = 16
# Vamos en el paso dónde k = 17
# Vamos en el paso dónde k = 18
# Vamos en el paso dónde k = 19
# Vamos en el paso dónde k = 20
# Vamos en el paso dónde k = 21
# Vamos en el paso dónde k = 22
# Vamos en el paso dónde k = 23
# Vamos en el paso dónde k = 24
# Vamos en el paso dónde k = 25
# Vamos en el paso dónde k = 26
# Vamos en el paso dónde k = 27
# Vamos en el paso dónde k = 28
# Vamos en el paso dónde k = 29
# Vamos en el paso dónde k = 30
# Vamos en el paso dónde k = 31
# ...

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez dónde se usa la f como la entropía de distribución de grados')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS',color='red',markersize=1)
plt.xscale('log')
plt.yscale('log')
plt.title('Gráfica de los índices de robustez dónde se usa la f como la entropía de distribución de grados')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes')
plt.grid(True)
plt.show()

# %%
indices_robustez_BA = []
indices_robustez_WS = []

for i in range(1,len(G_barabasi)):
    print(f"Vamos en el paso dónde k = {i}")
    G_1 = G_BA.copy() 
    G_2 = G_WS.copy()
    indice_robustez_BA = g.indice_robustez(G_1,en.entropia_distribucion_1,1,'degree',i)
    indice_robustez_WS = g.indice_robustez(G_2,en.entropia_distribucion_1,1,'degree',i)
    indices_robustez_BA.append(indice_robustez_BA)
    indices_robustez_WS.append(indice_robustez_WS)
# Out:
# Vamos en el paso dónde k = 1
# Vamos en el paso dónde k = 2
# Vamos en el paso dónde k = 3
# Vamos en el paso dónde k = 4
# Vamos en el paso dónde k = 5
# Vamos en el paso dónde k = 6
# Vamos en el paso dónde k = 7
# Vamos en el paso dónde k = 8
# Vamos en el paso dónde k = 9
# Vamos en el paso dónde k = 10
# Vamos en el paso dónde k = 11
# Vamos en el paso dónde k = 12
# Vamos en el paso dónde k = 13
# Vamos en el paso dónde k = 14
# Vamos en el paso dónde k = 15
# Vamos en el paso dónde k = 16
# Vamos en el paso dónde k = 17
# Vamos en el paso dónde k = 18
# Vamos en el paso dónde k = 19
# Vamos en el paso dónde k = 20
# Vamos en el paso dónde k = 21
# Vamos en el paso dónde k = 22
# Vamos en el paso dónde k = 23
# Vamos en el paso dónde k = 24
# Vamos en el paso dónde k = 25
# Vamos en el paso dónde k = 26
# Vamos en el paso dónde k = 27
# Vamos en el paso dónde k = 28
# Vamos en el paso dónde k = 29
# Vamos en el paso dónde k = 30
# Vamos en el paso dónde k = 31
# ...

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS',color='red',markersize=1)

plt.title('Gráfica de los índices de robustez dónde se usa la f como la entropía de distribución de grados')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes')
plt.grid(True)
plt.show()

# %%
k = [i for i in range(1,len(G_barabasi))]

plt.figure(figsize=(10,6))
plt.plot(k,indices_robustez_BA, label = 'Indice de robustez de red de BA',color='blue',markersize=1)
plt.plot(k,indices_robustez_WS, label = 'Indice de robustez de red de WS',color='red',markersize=1)
plt.xscale('log')
plt.yscale('log')
plt.title('Gráfica de los índices de robustez dónde se usa la f como la entropía de distribución de grados')
plt.xlabel('k')
plt.ylabel('Índices de robustez')
plt.legend(title='Modelos de redes')
plt.grid(True)
plt.show()
