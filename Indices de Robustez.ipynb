# %%
import graficas as g
import entropia as en
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
def w_1(G): 
    return 1/len(G)

# %%
def w_2(N):
    return 1/N

# %%
def w_3(G):
    distribucion_grados = g.obtener_distribucion_grados(G)
    print(distribucion_grados)
    probabilidades = [probabilidades for _,probabilidades in distribucion_grados]
    print(probabilidades)
    return probabilidades

# %%
G = g.crear_grafica('barabasi',10,2,0)
nx.draw(G,with_labels=True)
plt.show()
probabilidades = w_3(G)
# Out:
# [(2, 0.5), (3, 0.2), (4, 0.1), (6, 0.2)]
# [0.5, 0.2, 0.1, 0.2]
