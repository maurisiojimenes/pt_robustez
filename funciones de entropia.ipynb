# %%
import graficas as g
import matplotlib.pyplot as plt
import numpy as np
import entropia as en
import time
import importlib
import networkx as nx

# %%
importlib.reload(en)
importlib.reload(g)
# Out:
# <module 'graficas' from 'C:\\Users\\blond\\repositorios\\pt_robustez\\graficas.py'>

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_normalizada_1(G_barabasi)
entropia_1_watts = en.entropia_normalizada_1(G_watts)
entropia_2_barabasi = en.entropia_normalizada_2(G_barabasi)
entropia_2_watts = en.entropia_normalizada_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'random')
    G_watts = g.ataques(G_watts,'random')
    
    entropia_1_barabasi = en.entropia_normalizada_1(G_barabasi)
    entropia_1_watts = en.entropia_normalizada_1(G_watts)
    entropia_2_barabasi = en.entropia_normalizada_2(G_barabasi)
    entropia_2_watts = en.entropia_normalizada_2(G_watts)  
    
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H_norm(G) cuando la red tiene fallos')
plt.xlabel('porcentaje de nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 58.48191046714783

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_normalizada_1(G_barabasi)
entropia_1_watts = en.entropia_normalizada_1(G_watts)
entropia_2_barabasi = en.entropia_normalizada_2(G_barabasi)
entropia_2_watts = en.entropia_normalizada_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'degree')
    G_watts = g.ataques(G_watts,'degree')
    
    entropia_1_barabasi = en.entropia_normalizada_1(G_barabasi)
    entropia_1_watts = en.entropia_normalizada_1(G_watts)
    entropia_2_barabasi = en.entropia_normalizada_2(G_barabasi)
    entropia_2_watts = en.entropia_normalizada_2(G_watts)  
    
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H_norm(G) cuando la red tiene ataques')
plt.xlabel('porcentaje de nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 53.56935358047485

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_exponencial_1(G_barabasi)
entropia_1_watts = en.entropia_exponencial_1(G_watts)
entropia_2_barabasi = en.entropia_exponencial_2(G_barabasi)
entropia_2_watts = en.entropia_exponencial_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'random')
    G_watts = g.ataques(G_watts,'random')
    
    entropia_1_barabasi = en.entropia_exponencial_1(G_barabasi)
    entropia_1_watts = en.entropia_exponencial_1(G_watts)
    entropia_2_barabasi = en.entropia_exponencial_2(G_barabasi)
    entropia_2_watts = en.entropia_exponencial_2(G_watts)  
        
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H(G) cuando la red tiene fallos')
plt.xlabel('nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 13125.129239082336

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_exponencial_1(G_barabasi)
entropia_1_watts = en.entropia_exponencial_1(G_watts)
entropia_2_barabasi = en.entropia_exponencial_2(G_barabasi)
entropia_2_watts = en.entropia_exponencial_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'degree')
    G_watts = g.ataques(G_watts,'degree')
    
    entropia_1_barabasi = en.entropia_exponencial_1(G_barabasi)
    entropia_1_watts = en.entropia_exponencial_1(G_watts)
    entropia_2_barabasi = en.entropia_exponencial_2(G_barabasi)
    entropia_2_watts = en.entropia_exponencial_2(G_watts)  
        
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H(G) cuando la red sufre ataques por grado')
plt.xlabel('nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 248.27412843704224

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_distribucion_1(G_barabasi)
entropia_1_watts = en.entropia_distribucion_1(G_watts)
entropia_2_barabasi = en.entropia_distribucion_2(G_barabasi)
entropia_2_watts = en.entropia_distribucion_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'random')
    G_watts = g.ataques(G_watts,'random')
    
    entropia_1_barabasi = en.entropia_distribucion_1(G_barabasi)
    entropia_1_watts = en.entropia_distribucion_1(G_watts)
    entropia_2_barabasi = en.entropia_distribucion_2(G_barabasi)
    entropia_2_watts = en.entropia_distribucion_2(G_watts)  
        
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H_p(k)(G) de grados cuando la red tiene fallos')
plt.xlabel('porcentaje de nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 0.4077284336090088

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

entropia_1_barabasi = en.entropia_distribucion_1(G_barabasi)
entropia_1_watts = en.entropia_distribucion_1(G_watts)
entropia_2_barabasi = en.entropia_distribucion_2(G_barabasi)
entropia_2_watts = en.entropia_distribucion_2(G_watts)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))

entropias_1_barabasi = [entropia_1_barabasi]
entropias_1_watts = [entropia_1_watts]
entropias_2_barabasi = [entropia_2_barabasi]
entropias_2_watts = [entropia_2_watts]

inicio = time.time()

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'degree')
    G_watts = g.ataques(G_watts,'degree')
    
    entropia_1_barabasi = en.entropia_distribucion_1(G_barabasi)
    entropia_1_watts = en.entropia_distribucion_1(G_watts)
    entropia_2_barabasi = en.entropia_distribucion_2(G_barabasi)
    entropia_2_watts = en.entropia_distribucion_2(G_watts)  
        
    entropias_1_barabasi.append(entropia_1_barabasi)
    entropias_1_watts.append(entropia_1_watts)
    entropias_2_barabasi.append(entropia_2_barabasi)
    entropias_2_watts.append(entropia_2_watts)
    
fin = time.time()
print(f"el tiempo de ejecucion para obtener las entropias de la red fue: {fin - inicio}")

nodos_atacados = [i/N for i in range(N)]
nodos_atacados.insert(0,0)

plt.plot(nodos_atacados, entropias_1_barabasi, label = 'Entropia con ln en el modelo de BA', color = 'blue', markersize = 1)
plt.plot(nodos_atacados, entropias_1_watts, label = 'Entropia con ln en el modelo de WS', color = 'red', markersize = 1)
plt.plot(nodos_atacados, entropias_2_barabasi, label = 'Entropia con log base 10 en el modelo de BA', color = 'yellow', markersize = 1)
plt.plot(nodos_atacados, entropias_2_watts, label = 'Entropia con log base 10 en el modelo de WS', color = 'green', markersize = 1)

plt.title('Gráfica de H_p(k)(G) de grados cuando la red sufre ataques por grado')
plt.xlabel('porcentaje de nodos atacados')
plt.ylabel('Entropia')
plt.legend(title="Modelos de Redes y entropia", loc='best')
plt.grid(True)
plt.show()
# Out:
# el tiempo de ejecucion para obtener las entropias de la red fue: 0.37827134132385254

# %%
#A MODO DE PRUEBA QUIERO GRAFICAR LAS MEDIDAS DE ROBUSTEZ USUALES PARA VER EN QUE MOMENTO LA RED CON LOS PARÁMETROS DADOS 
#DEJA DE SER ROBUSTA Y COMPARARLO CON LO OBTENIDO CON LAS ENTROPIAS
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))


AD_barabasi = g.grado_promedio(G_barabasi)
D_barabasi = g.densidad(G_barabasi,N)
AD_watts = g.grado_promedio(G_watts)
D_watts = g.densidad(G_watts,N)

grados_promedio_barabasi = [AD_barabasi]
densidades_barabasi = [D_barabasi]
grados_promedio_watts = [AD_watts]
densidades_watts = [D_watts]

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'random')
    G_watts = g.ataques(G_watts,'random')
    
    AD_barabasi = g.grado_promedio(G_barabasi)
    D_barabasi = g.densidad(G_barabasi,N)
    AD_watts = g.grado_promedio(G_watts)
    D_watts = g.densidad(G_watts,N)
    
    grados_promedio_barabasi.append(AD_barabasi)
    densidades_barabasi.append(D_barabasi)
    grados_promedio_watts.append(AD_watts)
    densidades_watts.append(D_watts)
    
nodos_atacados = [i/N for i in range(N+1)]
    
# Crear las subgráficas
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Graficar Grados Promedio
ax1.plot(nodos_atacados, grados_promedio_barabasi, label='Grado Promedio con el modelo de BA', color='red', markersize=1)
ax1.plot(nodos_atacados, grados_promedio_watts, label='Grado Promedio con el modelo de WS', color='blue', markersize=1)
ax1.set_title('Grado Promedio de la Red')
ax1.set_xlabel('Nodos atacados')
ax1.set_ylabel('Grado Promedio')
ax1.grid(True)
ax1.legend(title='Modelos de Redes')

# Graficar Densidad
ax2.plot(nodos_atacados, densidades_barabasi, label='Densidad con el modelo de BA', color='brown', markersize=1)
ax2.plot(nodos_atacados, densidades_watts, label='Densidad con el modelo de WS', color='green', markersize=1)
ax2.set_title('Densidad de la Red')
ax2.set_xlabel('Nodos atacados')
ax2.set_ylabel('Densidad')
ax2.grid(True)
ax2.legend(title='Modelos de Redes')

# Ajustar espacio entre las subgráficas
plt.tight_layout()
plt.show()

# %%
#A MODO DE PRUEBA QUIERO GRAFICAR LAS MEDIDAS DE ROBUSTEZ USUALES PARA VER EN QUE MOMENTO LA RED CON LOS PARÁMETROS DADOS 
#DEJA DE SER ROBUSTA Y COMPARARLO CON LO OBTENIDO CON LAS ENTROPIAS
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

N = len(G_barabasi)
plt.figure(figsize=(10, 6))


AD_barabasi = g.grado_promedio(G_barabasi)
D_barabasi = g.densidad(G_barabasi,N)
AD_watts = g.grado_promedio(G_watts)
D_watts = g.densidad(G_watts,N)

grados_promedio_barabasi = [AD_barabasi]
densidades_barabasi = [D_barabasi]
grados_promedio_watts = [AD_watts]
densidades_watts = [D_watts]

for i in range(N):
    
    G_barabasi = g.ataques(G_barabasi,'degree')
    G_watts = g.ataques(G_watts,'degree')
    
    AD_barabasi = g.grado_promedio(G_barabasi)
    D_barabasi = g.densidad(G_barabasi,N)
    AD_watts = g.grado_promedio(G_watts)
    D_watts = g.densidad(G_watts,N)
    
    grados_promedio_barabasi.append(AD_barabasi)
    densidades_barabasi.append(D_barabasi)
    grados_promedio_watts.append(AD_watts)
    densidades_watts.append(D_watts)
    
nodos_atacados = [i/N for i in range(N+1)]
    
# Crear las subgráficas
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Graficar Grados Promedio
ax1.plot(nodos_atacados, grados_promedio_barabasi, label='Grado Promedio con el modelo de BA', color='red', markersize=1)
ax1.plot(nodos_atacados, grados_promedio_watts, label='Grado Promedio con el modelo de WS', color='blue', markersize=1)
ax1.set_title('Grado Promedio de la Red')
ax1.set_xlabel('Nodos atacados')
ax1.set_ylabel('Grado Promedio')
ax1.grid(True)
ax1.legend(title='Modelos de Redes')

# Graficar Densidad
ax2.plot(nodos_atacados, densidades_barabasi, label='Densidad con el modelo de BA', color='brown', markersize=1)
ax2.plot(nodos_atacados, densidades_watts, label='Densidad con el modelo de WS', color='green', markersize=1)
ax2.set_title('Densidad de la Red')
ax2.set_xlabel('Nodos atacados')
ax2.set_ylabel('Densidad')
ax2.grid(True)
ax2.legend(title='Modelos de Redes')

# Ajustar espacio entre las subgráficas
plt.tight_layout()
plt.show()

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

N = len(G_barabasi)
plt.figure(figsize=(10,6))

componentes_conexas_BA =[g.componentes_conexas(G_barabasi)]
componentes_conexas_WS = [g.componentes_conexas(G_watts)]

for i in range(N):
    G_barabasi = g.ataques(G_barabasi,'random')
    G_watts = g.ataques(G_watts,'random')
    
    numero_cc_BA = g.componentes_conexas(G_barabasi)
    numero_cc_WS = g.componentes_conexas(G_watts)
        
    componentes_conexas_BA.append(g.componentes_conexas(G_barabasi))
    componentes_conexas_WS.append(g.componentes_conexas(G_watts))

nodos_atacados = [i/N for i in range(N+1)]

plt.plot(nodos_atacados,componentes_conexas_BA,label='Componentes Conexas en el modelo de BA', color = 'red', markersize = 1)
plt.plot(nodos_atacados,componentes_conexas_WS,label='Componentes Conexas en el modelo de WS', color = 'blue', markersize = 1)
plt.title('Gráfica de las componentes conexas cuando la red tiene fallos')
plt.xlabel('% de nodos atacados')
plt.ylabel('Número de componentes conexas')
plt.grid(True)
plt.show()

# %%
G_barabasi = g.crear_grafica('barabasi',500,10,0)
G_watts = g.crear_grafica('watts',500,10,0.5)

N = len(G_barabasi)
plt.figure(figsize=(10,6))

componentes_conexas_BA =[g.componentes_conexas(G_barabasi)]
componentes_conexas_WS = [g.componentes_conexas(G_watts)]

for i in range(N):
    G_barabasi = g.ataques(G_barabasi,'degree')
    G_watts = g.ataques(G_watts,'degree')
    
    numero_cc_BA = g.componentes_conexas(G_barabasi)
    numero_cc_WS = g.componentes_conexas(G_watts)
        
    componentes_conexas_BA.append(g.componentes_conexas(G_barabasi))
    componentes_conexas_WS.append(g.componentes_conexas(G_watts))

nodos_atacados = [i/N for i in range(N+1)]

plt.plot(nodos_atacados,componentes_conexas_BA,label='Componentes Conexas en el modelo de BA', color = 'red', markersize = 1)
plt.plot(nodos_atacados,componentes_conexas_WS,label='Componentes Conexas en el modelo de WS', color = 'blue', markersize = 1)
plt.title('Gráfica de las componentes conexas cuando la red tiene ataques')
plt.xlabel('% de nodos atacados')
plt.ylabel('Número de componentes conexas')
plt.grid(True)
plt.show()
