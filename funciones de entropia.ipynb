# %%
import graficas as g
import matplotlib.pyplot as plt
import numpy as np
import entropia as en

# %%
G = g.crear_grafica('barabasi',1000,100,0)
N = len(G)
entropias = []
entropia = en.entropia_normalizada_1(G)
entropias.append(entropia)
print("\nLa entropia de la red antes de comenzar a atacar es:\n")
print(entropia)
for i in range(N):
    G = g.ataques(G,'random')
    entropia = en.entropia_normalizada_1(G)
    entropias.append(entropia)
    print("\nLa entropia despues del ", i," ataque es:\n")
    print(entropia)
# Out:
# La entropia de la red antes de comenzar a atacar es:
#
# 6.413756718179914
#
# La entropia despues del  0  ataque es:
#
# 6.424785175306415
#
# La entropia despues del  1  ataque es:
#
# 6.421411036746594
#
# La entropia despues del  2  ataque es:
#
# 6.433973117467239
#
# La entropia despues del  3  ataque es:
#
# 6.431144799710882
#
# La entropia despues del  4  ataque es:
#
# 6.430345718188305
#
# La entropia despues del  5  ataque es:
#
# 6.4288648596376
#
# La entropia despues del  6  ataque es:
#
# 6.427971918085051
#
# La entropia despues del  7  ataque es:
#
# 6.426773986296289
#
# La entropia despues del  8  ataque es:
#
# 6.425303834952932
#
# La entropia despues del  9  ataque es:
#
# 6.424240135869138
#
# La entropia despues del  10  ataque es:
#
# 6.435382636959631
#
# La entropia despues del  11  ataque es:
#
# 6.434342839563293
#
# La entropia despues del  12  ataque es:
#
# 6.433301274001582
#
# La entropia despues del  13  ataque es:
#
# 6.43189753432796
#
# ...
